# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarthagunna/AI/blob/main/model_based_vaccum372.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class ModelBasedRoomCleanerAgent:
    def __init__(self, room_size=(10, 10)):
        self.room_size = room_size
        # Initialize the room as a 10x10 grid with random 0 (clean) and 1 (dirty) cells
        self.grid = [[random.choice([0, 1]) for _ in range(room_size[1])] for _ in range(room_size[0])]
        # Initialize the agent's position randomly
        self.current_position = (random.randint(0, room_size[0] - 1), random.randint(0, room_size[1] - 1))
        # Initialize a model of the environment to track visited cells
        self.visited = [[False for _ in range(room_size[1])] for _ in range(room_size[0])]

    def display_room(self):
        # Display the current status of the room grid
        for row in self.grid:
            print(" ".join("C" if cell == 0 else "D" for cell in row))
        print("\n")

    def perceive(self):
        # Perceive the cleanliness of the current cell
        x, y = self.current_position
        return self.grid[x][y]

    def act(self):
        # Perform action based on the perception (clean the cell if dirty)
        x, y = self.current_position
        if self.perceive() == 1:  # If the current cell is dirty (1)
            print(f"Cell ({x}, {y}) is Dirty. Cleaning...")
            self.grid[x][y] = 0  # Clean the cell (set to 0)
            print(f"Cell ({x}, {y}) is now Clean.")
        else:
            print(f"Cell ({x}, {y}) is already Clean.")

        # Update the model to mark the cell as visited
        self.visited[x][y] = True

    def move(self):
        # Use the model to find the nearest unvisited dirty cell
        x, y = self.current_position
        for i in range(self.room_size[0]):
            for j in range(self.room_size[1]):
                if self.grid[i][j] == 1 and not self.visited[i][j]:
                    self.current_position = (i, j)
                    return
        # If no unvisited dirty cells are found, stop moving
        self.current_position = None

    def is_room_clean(self):
        # Check if the entire room is clean
        return all(cell == 0 for row in self.grid for cell in row)

    def run(self):
        # Display initial status of the room
        print("Initial Room Status:")
        self.display_room()

        steps = 0
        while not self.is_room_clean():
            print(f"\nStep {steps + 1}:")
            self.act()
            self.move()
            steps += 1
            if self.current_position is None:
                print("No more dirty cells detected. Stopping.")
                break

        # Display final status of the room
        print("\nFinal Room Status:")
        self.display_room()
        print(f"Room cleaned in {steps} steps.")

# Create and run the Model-Based Room Cleaner Agent
agent = ModelBasedRoomCleanerAgent()
agent.run()
# Out:
# Initial Room Status:
# D C D C C D D C D D
# D D C D C C C D D D
# C D D C C D C D D C
# D D C D D D C C D C
# D D C D D C D C C D
# D D D C D C C C C D
# D D D C D C C C C C
# D C D D C C D D D D
# C D D D C D D D C C
# C D C D C C D D C C
#
#
#
# Step 1:
# Cell (0, 1) is already Clean.
#
# Step 2:
# Cell (0, 0) is Dirty. Cleaning...
# Cell (0, 0) is now Clean.
#
# Step 3:
# Cell (0, 2) is Dirty. Cleaning...
# Cell (0, 2) is now Clean.
#
# Step 4:
# Cell (0, 5) is Dirty. Cleaning...
# Cell (0, 5) is now Clean.
#
# Step 5:
# Cell (0, 6) is Dirty. Cleaning...
# Cell (0, 6) is now Clean.
#
# Step 6:
# Cell (0, 8) is Dirty. Cleaning...
# Cell (0, 8) is now Clean.
#
# Step 7:
# Cell (0, 9) is Dirty. Cleaning...
# Cell (0, 9) is now Clean.
#
# Step 8:
# Cell (1, 0) is Dirty. Cleaning...
# Cell (1, 0) is now Clean.
#
# Step 9:
# Cell (1, 1) is Dirty. Cleaning...
# Cell (1, 1) is now Clean.
#
# Step 10:
# Cell (1, 3) is Dirty. Cleaning...
# Cell (1, 3) is now Clean.
#
# Step 11:
# Cell (1, 7) is Dirty. Cleaning...
# Cell (1, 7) is now Clean.
#
# Step 12:
# Cell (1, 8) is Dirty. Cleaning...
# Cell (1, 8) is now Clean.
#
# Step 13:
# Cell (1, 9) is Dirty. Cleaning...
# Cell (1, 9) is now Clean.
#
# Step 14:
# Cell (2, 1) is Dirty. Cleaning...
# Cell (2, 1) is now Clean.
#
# Step 15:
# Cell (2, 2) is Dirty. Cleaning...
# Cell (2, 2) is now Clean.
#
# Step 16:
# Cell (2, 5) is Dirty. Cleaning...
# Cell (2, 5) is now Clean.
#
# Step 17:
# Cell (2, 7) is Dirty. Cleaning...
# Cell (2, 7) is now Clean.
#
# Step 18:
# Cell (2, 8) is Dirty. Cleaning...
# Cell (2, 8) is now Clean.
#
# Step 19:
# Cell (3, 0) is Dirty. Cleaning...
# Cell (3, 0) is now Clean.
#
# Step 20:
# Cell (3, 1) is Dirty. Cleaning...
# Cell (3, 1) is now Clean.
#
# Step 21:
# Cell (3, 3) is Dirty. Cleaning...
# Cell (3, 3) is now Clean.
#
# Step 22:
# Cell (3, 4) is Dirty. Cleaning...
# Cell (3, 4) is now Clean.
#
# Step 23:
# Cell (3, 5) is Dirty. Cleaning...
# Cell (3, 5) is now Clean.
#
# Step 24:
# Cell (3, 8) is Dirty. Cleaning...
# Cell (3, 8) is now Clean.
#
# Step 25:
# Cell (4, 0) is Dirty. Cleaning...
# Cell (4, 0) is now Clean.
#
# Step 26:
# Cell (4, 1) is Dirty. Cleaning...
# Cell (4, 1) is now Clean.
#
# Step 27:
# Cell (4, 3) is Dirty. Cleaning...
# Cell (4, 3) is now Clean.
#
# Step 28:
# Cell (4, 4) is Dirty. Cleaning...
# Cell (4, 4) is now Clean.
#
# Step 29:
# Cell (4, 6) is Dirty. Cleaning...
# Cell (4, 6) is now Clean.
#
# Step 30:
# Cell (4, 9) is Dirty. Cleaning...
# Cell (4, 9) is now Clean.
#
# Step 31:
# Cell (5, 0) is Dirty. Cleaning...
# Cell (5, 0) is now Clean.
#
# Step 32:
# Cell (5, 1) is Dirty. Cleaning...
# Cell (5, 1) is now Clean.
#
# Step 33:
# Cell (5, 2) is Dirty. Cleaning...
# Cell (5, 2) is now Clean.
#
# Step 34:
# Cell (5, 4) is Dirty. Cleaning...
# Cell (5, 4) is now Clean.
#
# Step 35:
# Cell (5, 9) is Dirty. Cleaning...
# Cell (5, 9) is now Clean.
#
# Step 36:
# Cell (6, 0) is Dirty. Cleaning...
# Cell (6, 0) is now Clean.
#
# Step 37:
# Cell (6, 1) is Dirty. Cleaning...
# Cell (6, 1) is now Clean.
#
# Step 38:
# Cell (6, 2) is Dirty. Cleaning...
# Cell (6, 2) is now Clean.
#
# Step 39:
# Cell (6, 4) is Dirty. Cleaning...
# Cell (6, 4) is now Clean.
#
# Step 40:
# Cell (7, 0) is Dirty. Cleaning...
# Cell (7, 0) is now Clean.
#
# Step 41:
# Cell (7, 2) is Dirty. Cleaning...
# Cell (7, 2) is now Clean.
#
# Step 42:
# Cell (7, 3) is Dirty. Cleaning...
# Cell (7, 3) is now Clean.
#
# Step 43:
# Cell (7, 6) is Dirty. Cleaning...
# Cell (7, 6) is now Clean.
#
# Step 44:
# Cell (7, 7) is Dirty. Cleaning...
# Cell (7, 7) is now Clean.
#
# Step 45:
# Cell (7, 8) is Dirty. Cleaning...
# Cell (7, 8) is now Clean.
#
# Step 46:
# Cell (7, 9) is Dirty. Cleaning...
# Cell (7, 9) is now Clean.
#
# Step 47:
# Cell (8, 1) is Dirty. Cleaning...
# Cell (8, 1) is now Clean.
#
# Step 48:
# Cell (8, 2) is Dirty. Cleaning...
# Cell (8, 2) is now Clean.
#
# Step 49:
# Cell (8, 3) is Dirty. Cleaning...
# Cell (8, 3) is now Clean.
#
# Step 50:
# Cell (8, 5) is Dirty. Cleaning...
# Cell (8, 5) is now Clean.
#
# Step 51:
# Cell (8, 6) is Dirty. Cleaning...
# Cell (8, 6) is now Clean.
#
# Step 52:
# Cell (8, 7) is Dirty. Cleaning...
# Cell (8, 7) is now Clean.
#
# Step 53:
# Cell (9, 1) is Dirty. Cleaning...
# Cell (9, 1) is now Clean.
#
# Step 54:
# Cell (9, 3) is Dirty. Cleaning...
# Cell (9, 3) is now Clean.
#
# Step 55:
# Cell (9, 6) is Dirty. Cleaning...
# Cell (9, 6) is now Clean.
#
# Step 56:
# Cell (9, 7) is Dirty. Cleaning...
# Cell (9, 7) is now Clean.
# No more dirty cells detected. Stopping.
#
# Final Room Status:
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
# C C C C C C C C C C
#
#
# Room cleaned in 56 steps.
